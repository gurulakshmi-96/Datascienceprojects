# %%
import numpy as np

# %%
import pandas as pd

# %%
laliga = pd.read_csv("Laliga.csv")

# %%
laliga.head(10)
# Out:
#    Pos             Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0    1      Real Madrid       86   4385        2762     1647        552
# 1    2        Barcelona       86   4262        2762     1581        573
# 2    3  Atletico Madrid       80   3442        2614     1241        598
# 3    4         Valencia       82   3386        2664     1187        616
# 4    5  Athletic Bilbao       86   3368        2762     1209        633
# 5    6          Sevilla       73   2819        2408      990        531
# 6    7         Espanyol       82   2792        2626      948        608
# 7    8    Real Sociedad       70   2573        2302      864        577
# 8    9         Zaragoza       58   2109        1986      698        522
# 9   10       Real Betis       51   1884        1728      606        440
#
#   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 0       563     5947         3140       33        23     8      8     3     4
# ...

# %% [markdown]
# # 1.Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data.

# %%
laliga.replace("-",0,inplace = True)
laliga.head(10)
# Out:
#    Pos             Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0    1      Real Madrid       86   4385        2762     1647        552
# 1    2        Barcelona       86   4262        2762     1581        573
# 2    3  Atletico Madrid       80   3442        2614     1241        598
# 3    4         Valencia       82   3386        2664     1187        616
# 4    5  Athletic Bilbao       86   3368        2762     1209        633
# 5    6          Sevilla       73   2819        2408      990        531
# 6    7         Espanyol       82   2792        2626      948        608
# 7    8    Real Sociedad       70   2573        2302      864        577
# 8    9         Zaragoza       58   2109        1986      698        522
# 9   10       Real Betis       51   1884        1728      606        440
#
#   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 0       563     5947         3140       33        23     8      8     3     4
# ...

# %% [markdown]
# # 2.Print all the teams which have started playing between 1930-1980. Use “Debut” column

# %%
laliga[(laliga['Debut']>='1930') & (laliga['Debut']<='1980')]['Team']
# Out:
# 3                Valencia
# 5                 Sevilla
# 8                Zaragoza
# 9              Real Betis
# 10    Deportivo La Coruna
# 11             Celta Vigo
# 12             Valladolid
# 14         Sporting Gijon
# 15                Osasuna
# 16                 Malaga
# 17                 Oviedo
# 18               Mallorca
# 19             Las Palmas
# 21                Granada
# 22         Rayo Vallecano
# 23                  Elche
# 25               Hercules
# 26               Tenerife
# 27                 Murcia
# 28                 Alaves
# 29                Levante
# 30              Salamanca
# 31               Sabadell
# 32                  Cadiz
# 34              Castellon
# 37                Cordoba
# 39             Recreativo
# 40              Burgos CF
# 41             Pontevedra
# 46              Gimnastic
# 49               Alcoyano
# 50                   Jaen
# 52             AD Almeria
# 54                 Lleida
# 57                 Condal
# ...

# %% [markdown]
# # Print the list of teams which came Top 5 in terms of points

# %%
laliga1 = laliga.astype({'Points' : 'int64','GoalsFor' :'int64','GoalsAgainst':'int64','GamesWon' : 'int64','GamesPlayed': 'int64'})

# %%
laliga1.dtypes
# Out:
# Pos               int64
# Team             object
# Seasons           int64
# Points            int64
# GamesPlayed       int64
# GamesWon          int64
# GamesDrawn       object
# GamesLost        object
# GoalsFor          int64
# GoalsAgainst      int64
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp    object
# BestPosition      int64
# dtype: object

# %%
laliga1.nlargest(5,'Points')[['Team','Points']]
# Out:
#               Team  Points
# 0      Real Madrid    4385
# 1        Barcelona    4262
# 2  Atletico Madrid    3442
# 3         Valencia    3386
# 4  Athletic Bilbao    3368

# %% [markdown]
# # Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference. (5 points)

# %%
def Goal_diff_count(x,y):
    a = x-y
    return(a)

# %%
laliga1['Goal_diff'] = Goal_diff_count(laliga1['GoalsFor'],laliga1['GoalsAgainst'])

# %%
laliga1.nsmallest(1,'Goal_diff')[['Team','Goal_diff']]
# Out:
#                 Team  Goal_diff
# 13  Racing Santander       -525

# %%
laliga1.nlargest(1,'Goal_diff')[['Team','Goal_diff']]
# Out:
#           Team  Goal_diff
# 0  Real Madrid       2807

# %% [markdown]
# # Create a new column with the name “Winning Percent” and append it to the data set

# %%
def winning_perc(x):
    GamesWon ,GamesPlayed = x
    if (GamesPlayed == 0):
        Winning_Percent = 0
    else:
        Winning_Percent  = (GamesWon/GamesPlayed) *100 
    return Winning_Percent

# %%
laliga1['Winning Percent'] = laliga1[['GamesWon','GamesPlayed']].apply(winning_perc, axis = 1)

# %%
laliga1.head(10)
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 0    1      Real Madrid       86    4385         2762      1647        552
# 1    2        Barcelona       86    4262         2762      1581        573
# 2    3  Atletico Madrid       80    3442         2614      1241        598
# 3    4         Valencia       82    3386         2664      1187        616
# 4    5  Athletic Bilbao       86    3368         2762      1209        633
# 5    6          Sevilla       73    2819         2408       990        531
# 6    7         Espanyol       82    2792         2626       948        608
# 7    8    Real Sociedad       70    2573         2302       864        577
# 8    9         Zaragoza       58    2109         1986       698        522
# 9   10       Real Betis       51    1884         1728       606        440
#
#   GamesLost  GoalsFor  GoalsAgainst  ... Third Fourth Fifth Sixth   T  \
# 0       563      5947          3140  ...     8      8     3     4  79
# ...

# %%
laliga1.nlargest(5,'Winning Percent')[['Team','Winning Percent']]
# Out:
#               Team  Winning Percent
# 0      Real Madrid        59.630702
# 1        Barcelona        57.241130
# 2  Atletico Madrid        47.475134
# 3         Valencia        44.557057
# 4  Athletic Bilbao        43.772629

# %% [markdown]
# # Group teams based on their “Best position” and print the sum of their points for all positions

# %%
laliga1.groupby(["Team","BestPosition"])["Points"].agg(["sum"]).sort_values('sum', ascending=True)
# Out:
#                                 sum
# Team             BestPosition
# Girona           9                0
# Cultural Leonesa 15              14
# Atletico Tetuan  16              19
# Condal           16              22
# Xerez            20              34
# ...                             ...
# Athletic Bilbao  1             3368
# Valencia         1             3386
# Atletico Madrid  1             3442
# Barcelona        1             4262
# Real Madrid      1             4385
#
# [61 rows x 1 columns]
